# %%
"""
Programmable turtle graphics

Use what you've learned about lists, loop, cycle, slice and zip to draw a pattern
"""

import turtle                           # Tell Python we want to work with the turtle
turtle.setup(600,600,0,0)               # Set the size of the window

t = turtle.Turtle()                  # Create a turtle named tina

t.shape('turtle')                    # Set the shape of the turtle to a turtle.speed(2)                           # Make the turtle move as fast, but not too fast.  # Create a turtle like in previous programs, like 04_Crazy_Tina.py

colors = ['blue','cyan','navy','green','red','yellow','purple'] # Make a list of colors

directions = [ # Create a list of directions and angles
    ( <'1','14','28','34','56','71','89'>, <'1','14','28','34','56','71','89'> ),
    ( <'1','14','28','34','56','71','89'>, <'1','14','28','34','56','71','89'> ), ... # Add more
]

# Zip the colors and directions together, then unpack them. THere is a good example of this
# in 10_More_iterables.ipynb in the discussion of zip()

for colors, directions in zip(colors , directions):
    t.color( ... )
    t.forward( ... )
    t.left( ... )

# Don't forget the special way to end a turtle program. 
turtle.exitonclick()
